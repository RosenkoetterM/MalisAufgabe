# %% [markdown]
# # Line by line

# %%
# CSV Datei hatte ein UTF-8 encoding Problem
for line in open("kueShortExport (1).csv", encoding="ISO-8859-15"):
    print(line)
# Out:
# #DocumentKey;#3000;#3100;#31nn;#3140;#3160;#3162;#3180;#3189;#3200;#3248;#3300;#8566;#99fm
#
# kue     00050382;50382;Adams, Edward T.;Edward T. Adams;m;Bürgertum;Fotograf;1901-3000;"Urheberrecht (Nachweis bis 3000; Name unvollständig)";Vereinigte Staaten;US-amerikanisch;1901;nicht VG BILD-KUNST r.V.,2012;AKL 00
#
# kue     02530645;2530645;Adamo, Max;Max Adamo;m;Bürgertum;Maler & Illustrator;1852-1901;gemeinfrei;Deutschland;deutsch;;;
#
# kue     04011001;4011001;Adamson, Robert;Robert Adamson;m;;Fotograf;1836-1848;gemeinfrei;England;englisch;;;AKL 00
#
# kue     04020003;4020003;Adamson, Prescott;Prescott Adamson;m;;Fotograf;1901-1904;Urheberrecht? (Nachweis bis 1904);Vereinigte Staaten;US-amerikanisch;1901;;AKL 00
#
# kue     05110039;5110039;Adams, Ansel;Ansel Adams;m;;Fotograf;1917-1984;Urheberrecht (1984 gestorben);Vereinigte Staaten;US-amerikanisch;;nicht VG BILD-KUNST r.V.,2011;
#
# ...

# %% [markdown]
# # Mit Pandas

# %%
import pandas as pd
artists = pd.read_csv("kueShortExport (1).csv", encoding="ISO-8859-15", sep=";", index_col="#DocumentKey")

# %%
artists.head()
# Out:
#                     #3000              #3100             #31nn #3140  \
# #DocumentKey
# kue     00050382    50382   Adams, Edward T.   Edward T. Adams     m
# kue     02530645  2530645         Adamo, Max         Max Adamo     m
# kue     04011001  4011001    Adamson, Robert    Robert Adamson     m
# kue     04020003  4020003  Adamson, Prescott  Prescott Adamson     m
# kue     05110039  5110039       Adams, Ansel       Ansel Adams     m
#
#                       #3160                #3162      #3180  \
# #DocumentKey
# kue     00050382  Bürgertum             Fotograf  1901-3000
# kue     02530645  Bürgertum  Maler & Illustrator  1852-1901
# kue     04011001        NaN             Fotograf  1836-1848
# kue     04020003        NaN             Fotograf  1901-1904
# kue     05110039        NaN             Fotograf  1917-1984
#
#                                                               #3189  \
# #DocumentKey
# kue     00050382  Urheberrecht (Nachweis bis 3000; Name unvollst...
# ...

# %%
#Liste mit Dokumentnummer und 
artists [['#3189', '#3300', "#8566"]]
# Out:
#                                                               #3189  \
# #DocumentKey
# kue     00050382  Urheberrecht (Nachweis bis 3000; Name unvollst...
# kue     02530645                                         gemeinfrei
# kue     04011001                                         gemeinfrei
# kue     04020003                  Urheberrecht? (Nachweis bis 1904)
# kue     05110039                      Urheberrecht (1984 gestorben)
# kue     08003836                                         gemeinfrei
# kue     08120462                  Urheberrecht? (Nachweis bis 1900)
# kue     10010155                                         gemeinfrei
# kue     10010167                   Urheberrecht (Nachweis bis 3000)
# kue     11000731                    gemeinfrei (Name unvollständig)
# kue     11000754                                         gemeinfrei
# kue     11000761  Urheberrecht? (Nachweis bis 1900; Name unvolls...
# kue     11001053                    gemeinfrei (Name unvollständig)
# ...

# %%
# Sortierung nach gemeinfreien Künstlern geht schon mal:
artists[artists['#3189'] =="gemeinfrei"]
# Out:
#                      #3000                       #3100  \
# #DocumentKey
# kue     02530645   2530645                  Adamo, Max
# kue     04011001   4011001             Adamson, Robert
# kue     08003836   8003836        Adams, ? (1601/1700)
# kue     10010155  10010155  Adams, Katherine Langhorne
# kue     11000754  11000754     Adamsson, Johan Fredrik
# kue     14000251  14000251          Adams, John Quincy
# kue     20037799  20037799                Adams, Anton
# kue     20101123  20101123        Adams, Johann Rudolf
# kue     20101154  20101154       Adams, George William
# kue     20131351  20131351           Adams-Acton, John
# kue     20222356  20222356             Adamolli, Luigi
#
#                                       #31nn #3140      #3160  \
# #DocumentKey
# kue     02530645                  Max Adamo     m  Bürgertum
# kue     04011001             Robert Adamson     m        NaN
# kue     08003836                    ? Adams   NaN        NaN
# ...

# %%
# wie bekomme ich eine Liste mit allen NICHT-"gemeinfrei"?
noVGBild = artists[artists['#3189'] =="/n"]

# %%
# Mail alle noVGBild an martha.rosenkoetter@gmail.com:
import smtplib
smtpObj = smtplib.SMTP("smtp.gmail.com", 587)
smtpObj.ehlo()
smtpObj.starttls()
smtpObj.login("martha.rosenkoetter@gmail.com", "WONTTELLYA")
smtpObj.sendmail("martha.rosenkoetter@gmail.com", "Subject: New VGBild-list to proove")
smtpObj.quit()

## wie füge ich hier eine Datei (FehlenderVGBild) automatisch ein mit einem timestamp?
# Out:
# ---------------------------------------------------------------------------
# SMTPAuthenticationError                   Traceback (most recent call last)
# <ipython-input-51-f0f36c4c5dda> in <module>
#       4 smtpObj.ehlo()
#       5 smtpObj.starttls()
# ----> 6 smtpObj.login("martha.rosenkoetter@gmail.com", "M.i.r.h2K")
#       7 smtpObj.sendmail("martha.rosenkoetter@gmail.com", "Subject: New VGBild-list to proove")
#       8 smtpObj.quit()
#
# ~\Anaconda3\lib\smtplib.py in login(self, user, password, initial_response_ok)
#     728
#     729         # We could not login successfully.  Return result of last attempt.
# --> 730         raise last_exception
#     731
#     732     def starttls(self, keyfile=None, certfile=None, context=None):
#
# ~\Anaconda3\lib\smtplib.py in login(self, user, password, initial_response_ok)
#     719                 (code, resp) = self.auth(
#     720                     authmethod, getattr(self, method_name),
# ...

# %%
# Anhang an eine Mail mit timestamp:
def send_results_by_email(to, filename=NoVGBild):
    """Send an email with the NoVGBild data attached"""
    with open(filename, 'r') as csvfile:
        now = datetime.now().strftime("%m-%d-%Y %H:%M")
        email_message = EmailMessage(
            subject=f"noVGBild data (collected {now})",
            body=f"Script run with the following settings module: '{settings.SETTINGS_MODULE}'",
            to=to,
            attachments=[('NoVGBild.csv', csvfile.read(), 'text/csv')])
        email_message.send()
    print(f"Email sent to {to}!")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-49-87448ad94c25> in <module>
# ----> 1 def send_results_by_email(to, filename=NoVGBild):
#       2     """Send an email with the NoVGBild data attached"""
#       3     with open(filename, 'r') as csvfile:
#       4         now = datetime.now().strftime("%m-%d-%Y %H:%M")
#       5         email_message = EmailMessage(
#
# NameError: name 'NoVGBild' is not defined
