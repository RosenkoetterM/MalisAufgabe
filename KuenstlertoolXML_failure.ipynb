# %% [markdown]
# # Schnittstelle
# Da es noch keine OpenAccess-Schnittstelle für die Online-Datenbank www.bildindex.de gibt, wird hier die Exportdatei für Testzwecke auf dem lokalen Privat-Server gespeichert

# %%
import pandas as pd

# %%
## [kue_file = "fme-private-KUE20190501.xml"]
Die komplette xml Datei ist zu sperrig um damit zu arbeiten.
Ein kleiner Export aus der Datenbank wurde zu Testzwecken erstellt.

# %%
# Sax-Parser import zum Auslesen von xml
import xml.sax
class MyHandler ( xml.sax.ContentHandler):
    def __init__( self):
        xml.sax.ContentHandler.__init__( self)
        self.element_name2count = {}
        
    def startElement( self, name, attrs):
        self.element_name2count[ name] = self.element_name2count.get( name, 0) + 1
        
kue_file = "kueShortExport.xml"
handler = MyHandler()
xml.sax.parse(kue_file, handler)

# %%
# sort elements according to their count - hier verstehe ich nicht, wie ich und vor allem was definieren soll.
to_sort = [(count,name) for name,count in handler.element_name2count.iteritems()]
to_sort.sort( reverse=True)
for count,name in to_sort:
    print (name,count)

# %%
for line in open(kue_file):
   print (line)
# Out:
# ï»¿<?xml version="1.0" encoding="UTF-8"?>
#
# <h1:DocumentSet xmlns:h1="http://www.startext.de/HiDA/DefService/XMLSchema">
#
#   <h1:ContentInfo>
#
#     <h1:Format>HIDA-DOC1-XML</h1:Format>
#
#     <h1:CreationDate>19.07.2019 07:22:55:214</h1:CreationDate>
#
#   </h1:ContentInfo>
#
#   <!-- Document sorting key: '{ kue     00050382, { ttText:00050382  } }' -->
#
#   <h1:Document DocKey="kue     00050382" FieldsCount="14">
#
#     <h1:Block Type="kue" CreationDate="24.02.2018 12:08:45" CreatorID="HidaAdmin" ChangeDate="24.02.2018 12:08:45" ChangerID="HidaAdmin" OwnerID="HidaAdmin" FieldsCount="13">
#
#       <h1:Field Type="3000" Value="00050382"/>
#
#       <h1:Field Type="3100" Value="Adams, Edward T."/>
#
#       <h1:Field Type="31nn" Value="Edward T. Adams"/>
#
#       <h1:Field Type="3140" Value="m"/>
#
#       <h1:Field Type="3160" Value="BÃ¼rgertum"/>
#
#       <h1:Field Type="3162" Value="Fotograf"/>
#
#       <h1:Field Type="3180" Value="1901-3000"/>
#
# ...

# %% [markdown]
# # Problem:
# ## Dataframe - Wie frame ich XML?
# Das weitere Vorgehen ist mir unbekannt
#
# ## UTF-8: wie matche ich die Satzzeichen?

# %%
def

# %% [markdown]
# # Step 2: search

# %%
# Definition: folgende Zeilen müssen Vorhanden sein. 
3000 = 
30gn = 
3189 = 
# Umbenennen eines Type?
3000 = "Dok_ID"
30gn = "Norm_ID" 
3189 = "VGBild"
# loop: Eine Datei fängt an mit Dok_ID und endet mit VGBild. 
# mache eine LIste aus Norm_ID = "false" 
# benenne sie mit "noNorm_ID"
def noNorm_ID ():
    if 

Dok_ID ="*"
Norm_ID ="false" 
# mache eine Liste aus VGBild = "false" 
# bennene sie mit "FehlenderVGBild"
Dok_ID ="*"
VGBild ="*"
# suche Alle Dok_ID mit Mehrfachvergabe von ULAN, GND oder VIAF bei Norm_ID
# erstelle eine Liste
# benenne Sie mit "MehrfachvergabeNorm_ID"
...

# %% [markdown]
# # Step 3: mail

# %%
# Mail alle doppelt vergebenen Norm_ID : See´: automatetheboringstuff.com for python

# %% [markdown]
# # Step 4: matching GND

# %%
# nimm "FehlendeNorm_ID"
# patternmatch mit Liste: 3000, 30gn, 3100, 3105, 3270, 3330, 3290
# matche liste "FehlendeNorm_ID" mit Personennorm https://data.dnb.de/opendata/
# match 100 % erfolgreich, dann füge 30gn in Quelldatei ein

# %%
# nimm "FehlenderAGBild"
# patternmatch mit Liste: 3000, 30gn, 3100, 3105, 3270, 3330, 3290
# matche liste "FehlendeNorm_ID" mit Personennorm https://data.dnb.de/opendata/
